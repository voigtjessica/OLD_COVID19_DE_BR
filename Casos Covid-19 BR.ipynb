# %%
import pandas as pd

# %%
df = pd.read_csv('caso_full.csv.gz', compression='gzip', header=0, sep=',', quotechar='"', error_bad_lines=False)

# %%
df.shape
# Out:
# (1624096, 18)

# %%
df[0:3]
# Out:
#          city  city_ibge_code        date  epidemiological_week  \
# 0  Rio Branco       1200401.0  2020-03-17                202012
# 1         NaN            12.0  2020-03-17                202012
# 2  Rio Branco       1200401.0  2020-03-18                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 0              413418.0                   407319.0    False        False
# 1              894470.0                   881935.0    False        False
# 2              413418.0                   407319.0    False        False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 0                         3                                        0.72566
# 1                         3                                        0.33539
# 2                         3                                        0.72566
#
#   last_available_date  last_available_death_rate  last_available_deaths  \
# ...

# %%
# Data do dia que eu baixei esse banco:
df.last_available_date.max()
# Out:
# '2021-02-23'

# %%
df_states = df.query('place_type == "state" & state=="SP"')
df_states[0:5]

#11.422.973 Rs
#46.289.333
# Out:
#         city  city_ibge_code        date  epidemiological_week  \
# 1432033  NaN            35.0  2020-02-25                202009
# 1432035  NaN            35.0  2020-02-26                202009
# 1432037  NaN            35.0  2020-02-27                202009
# 1432039  NaN            35.0  2020-02-28                202009
# 1432041  NaN            35.0  2020-02-29                202009
#
#          estimated_population  estimated_population_2019  is_last  \
# 1432033            46289333.0                 45919049.0    False
# 1432035            46289333.0                 45919049.0    False
# 1432037            46289333.0                 45919049.0    False
# 1432039            46289333.0                 45919049.0    False
# 1432041            46289333.0                 45919049.0    False
#
#          is_repeated  last_available_confirmed  \
# 1432033        False                         1
# 1432035        False                         1
# ...
